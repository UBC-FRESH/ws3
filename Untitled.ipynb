# %%
# !python setup.py develop
# Out:
# /opt/jupyterhub/lib/python3.8/site-packages/setuptools/dist.py:473: UserWarning: Normalizing '0.0.1-post3' to '0.0.1.post3'
#   warnings.warn(
# running develop
# running egg_info
# creating ws3.egg-info
# writing ws3.egg-info/PKG-INFO
# writing dependency_links to ws3.egg-info/dependency_links.txt
# writing requirements to ws3.egg-info/requires.txt
# writing top-level names to ws3.egg-info/top_level.txt
# writing manifest file 'ws3.egg-info/SOURCES.txt'
# reading manifest file 'ws3.egg-info/SOURCES.txt'
# writing manifest file 'ws3.egg-info/SOURCES.txt'
# running build_ext
# Creating /opt/jupyterhub/lib/python3.8/site-packages/ws3.egg-link (link to .)
# Adding ws3 0.0.1.post3 to easy-install.pth file
#
# Installed /media/data/project/gparadis/ws3
# Processing dependencies for ws3==0.0.1.post3
# Searching for scipy==1.6.0
# Best match: scipy 1.6.0
# Adding scipy 1.6.0 to easy-install.pth file
#
# Using /opt/jupyterhub/lib/python3.8/site-packages
# Searching for rasterio==1.1.8
# ...

# %%
import ws3

# %%
ws3.__file__
# Out:
# '/media/data/project/gparadis/ws3/ws3/__init__.py'
